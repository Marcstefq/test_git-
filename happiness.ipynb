# %%
import pandas as pd
df=pd.read_csv('world-happiness-report-2021.csv')
display(df.head(5))
df.fillna(0)
display(df.info())
# Out:
#   Country name Regional indicator  ...  Explained by: Perceptions of corruption  Dystopia + residual
# 0      Finland     Western Europe  ...                                    0.481                3.253
# 1      Denmark     Western Europe  ...                                    0.485                2.868
# 2  Switzerland     Western Europe  ...                                    0.413                2.839
# 3      Iceland     Western Europe  ...                                    0.170                2.967
# 4  Netherlands     Western Europe  ...                                    0.384                2.798
#
# [5 rows x 20 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
# ...
